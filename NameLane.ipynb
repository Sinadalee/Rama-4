# %%
# <intersection>_<ApproachingDirection>_<EdgeIndex>_<LaneIndex>_<GoingDirection>
# KASEMRAT
KASEMRAT_EB_0_0_XSXX = '459551209#3_0'
KASEMRAT_EB_0_1_XSXX = '459551209#3_1'
KASEMRAT_EB_0_2_XSXX = '459551209#3_2'
KASEMRAT_EB_0_3_XSRT = '459551209#3_3'
KASEMRAT_EB_1_0_LSXX = '459551209#0_0'
KASEMRAT_EB_1_1_XSXX = '459551209#0_1'
KASEMRAT_EB_1_2_XSXX = '459551209#0_2'
KASEMRAT_EB_1_3_XSXX = '459551209#0_3'
KASEMRAT_EB_2_0_LSXX = '820340552#2_0'
KASEMRAT_EB_2_1_XSXX = '820340552#2_1'
KASEMRAT_EB_2_2_XSXX = '820340552#2_2'
KASEMRAT_EB_3_0_LSXX = '820340552#1_0'
KASEMRAT_EB_3_1_XSXX = '820340552#1_1'
KASEMRAT_EB_3_2_XSXX = '820340552#1_2'
KASEMRAT_EB_4_0_LSXX = '820340552#0_0'
KASEMRAT_EB_4_1_XSXX = '820340552#0_1'
KASEMRAT_EB_4_2_XSXX = '820340552#0_2'
KASEMRAT_EB_5_0_LSXX = '153225678#3_0'
KASEMRAT_EB_5_1_XSXX = '153225678#3_1'
KASEMRAT_EB_5_2_XSXX = '153225678#3_2'
KASEMRAT_EB_5_3_XSXX = '153225678#3_3'
KASEMRAT_EB_6_0_LSXX = '153225678#2_0'
KASEMRAT_EB_6_1_XSXX = '153225678#2_1'
KASEMRAT_EB_6_2_XSXX = '153225678#2_2'
KASEMRAT_EB_6_3_XSXX = '153225678#2_3'
KASEMRAT_EB_7_0_LSXX = '153225678#1_0'
KASEMRAT_EB_7_1_XSXX = '153225678#1_1'
KASEMRAT_EB_7_2_XSXX = '153225678#1_2'
KASEMRAT_EB_7_3_XSXX = '153225678#1_3'
KASEMRAT_EB_8_0_XSXX = '153225678#1-AddedOnRampEdge_0'
KASEMRAT_EB_8_1_XSXX = '153225678#1-AddedOnRampEdge_1'
KASEMRAT_EB_8_2_XSXX = '153225678#1-AddedOnRampEdge_2'
KASEMRAT_EB_8_3_XSXX = '153225678#1-AddedOnRampEdge_3'
KASEMRAT_EB_8_4_XSXX = '153225678#1-AddedOnRampEdge_4'
KASEMRAT_EB_9_0_XSXX = '153225678#0_0'
KASEMRAT_EB_9_1_XSXX = '153225678#0_1'
KASEMRAT_EB_9_2_XSXX = '153225678#0_2'
KASEMRAT_EB_9_3_XSXX = '153225678#0_3'

KASEMRAT_NB_0_0_LSXX = '321845933#3_0'
KASEMRAT_NB_0_1_XSXX = '321845933#3_1'
KASEMRAT_NB_0_2_XSRX = '321845933#3_2'
KASEMRAT_NB_1_0_LSXX = '321845933#1_0'
KASEMRAT_NB_1_1_XSXX = '321845933#1_1'
KASEMRAT_NB_1_2_XSXX = '321845933#1_2'
KASEMRAT_NB_2_0_XSXX = '321845933#2_0'
KASEMRAT_NB_2_1_XSXX = '321845933#2_1'
KASEMRAT_NB_3_0_LSXX = '482384842#2_0'
KASEMRAT_NB_3_1_XSXX = '482384842#2_1'
KASEMRAT_NB_3_2_XSXX = '482384842#2_2'
KASEMRAT_NB_3_3_XSRT = '482384842#2_3'
KASEMRAT_NB_4_0_XSXX = '482384842#2-AddedOnRampNode_0'
KASEMRAT_NB_4_1_XSXX = '482384842#2-AddedOnRampNode_1'
KASEMRAT_NB_4_2_XSXX = '482384842#2-AddedOnRampNode_2'
KASEMRAT_NB_5_0_XSXX = '482384842#1-AddedOnRampEdge_0'
KASEMRAT_NB_5_1_XSXX = '482384842#1-AddedOnRampEdge_1'
KASEMRAT_NB_5_2_XSXX = '482384842#1-AddedOnRampEdge_2'
KASEMRAT_NB_5_3_XSXX = '482384842#1-AddedOnRampEdge_3'
KASEMRAT_NB_6_0_XSXX = '482384842#0_0'
KASEMRAT_NB_6_1_XSXX = '482384842#0_1'
KASEMRAT_NB_6_2_XSXX = '482384842#0_2'
KASEMRAT_NB_7_0_LSXX = '153225687#13_0'
KASEMRAT_NB_7_1_XSXX = '153225687#13_1'
KASEMRAT_NB_7_2_XSRX = '153225687#13_2'
KASEMRAT_NB_8_0_LSXX = '321845932#1_0'
KASEMRAT_NB_8_1_XSXX = '321845932#1_1'
KASEMRAT_NB_8_2_XSRT = '321845932#1_2'

KASEMRAT_WB_0_0_LSXX = '820373194#0_0'
KASEMRAT_WB_0_1_XSXX = '820373194#0_1'
KASEMRAT_WB_0_2_XSXX = '820373194#0_2'
KASEMRAT_WB_1_0_XSXX = '820373193_0'
KASEMRAT_WB_1_1_XSXX = '820373193_1'
KASEMRAT_WB_1_2_XSXX = '820373193_2'
KASEMRAT_WB_1_3_XSRX = '820373193_3'
KASEMRAT_WB_2_0_XSXX = '825786433#6_0'
KASEMRAT_WB_2_1_XSXX = '825786433#6_1'
KASEMRAT_WB_2_2_XSXX = '825786433#6_2'
KASEMRAT_WB_3_0_LSXX = '825786433#3_0'
KASEMRAT_WB_3_1_XSXX = '825786433#3_1'
KASEMRAT_WB_3_2_XSXX = '825786433#3_2'

# %%
# KLONGTEI
KLONGTEI_EB_0_0_XSXX = '825786400_0'
KLONGTEI_EB_0_1_XSXX = '825786400_1'
KLONGTEI_EB_0_2_XSXX = '825786400_2'
KLONGTEI_EB_0_3_XSXX = '825786400_3'
KLONGTEI_EB_0_4_XSRT = '825786400_4'
KLONGTEI_EB_1_0_XSXX = '459492912#1_0'
KLONGTEI_EB_1_1_XSXX = '459492912#1_1'
KLONGTEI_EB_1_2_XSXX = '459492912#1_2'
KLONGTEI_EB_1_3_XSXX = '459492912#1_3'
KLONGTEI_EB_2_0_LSXX = '459492912#0_0'
KLONGTEI_EB_2_1_XSXX = '459492912#0_1'
KLONGTEI_EB_2_2_XSXX = '459492912#0_2'
KLONGTEI_EB_2_3_XSXX = '459492912#0_3'
KLONGTEI_EB_3_0_LSXX = '752225467_0'
KLONGTEI_EB_3_1_XSXX = '752225467_1'
KLONGTEI_EB_4_0_XSXX = '825786397_0'
KLONGTEI_EB_4_1_XSXX = '825786397_1'
KLONGTEI_EB_4_2_XSXX = '825786397_2'
KLONGTEI_EB_4_3_XSXX = '825786397_3'
KLONGTEI_EB_4_4_XSXX = '825786397_4'
KLONGTEI_EB_5_0_XSXX = '825786383#0_0'
KLONGTEI_EB_5_1_XSXX = '825786383#0_1'
KLONGTEI_EB_5_2_XSXX = '825786383#0_2'
KLONGTEI_EB_5_3_XSXX = '825786383#0_3'

KLONGTEI_NB_0_0_LSXX = '25047974#2_0'
KLONGTEI_NB_0_1_XSXX = '25047974#2_1'
KLONGTEI_NB_0_2_XSXX = '25047974#2_2'
KLONGTEI_NB_0_3_XSRT = '25047974#2_3'
KLONGTEI_NB_1_0_LSXX = '25047974#1_0'
KLONGTEI_NB_1_1_XSXX = '25047974#1_1'
KLONGTEI_NB_1_2_XSXX = '25047974#1_2'
KLONGTEI_NB_1_3_XSXX = '25047974#1_3'
KLONGTEI_NB_2_0_LSXX = '25047974#0_0'
KLONGTEI_NB_2_1_XSXX = '25047974#0_1'
KLONGTEI_NB_2_2_XSXX = '25047974#0_2'
KLONGTEI_NB_2_3_XSXX = '25047974#0_3'

KLONGTEI_WB_0_0_LSXX = '481971011#1_0'
KLONGTEI_WB_0_1_XSXX = '481971011#1_1'
KLONGTEI_WB_0_2_XSXX = '481971011#1_2'
KLONGTEI_WB_0_3_XSXX = '481971011#1_3'
KLONGTEI_WB_0_4_XSXX = '481971011#1_4'
KLONGTEI_WB_1_0_XSXX = '481971011#1-AddedOnRampEdge_0'
KLONGTEI_WB_1_1_XSXX = '481971011#1-AddedOnRampEdge_1'
KLONGTEI_WB_1_2_XSXX = '481971011#1-AddedOnRampEdge_2'
KLONGTEI_WB_1_3_XSXX = '481971011#1-AddedOnRampEdge_3'
KLONGTEI_WB_1_4_XSXX = '481971011#1-AddedOnRampEdge_4'
KLONGTEI_WB_1_5_XSXX = '481971011#1-AddedOnRampEdge_5'
KLONGTEI_WB_2_0_XSXX = '481971011#0_0'
KLONGTEI_WB_2_1_XSXX = '481971011#0_1'
KLONGTEI_WB_2_2_XSXX = '481971011#0_2'
KLONGTEI_WB_2_3_XSXX = '481971011#0_3'
KLONGTEI_WB_2_4_XSXX = '481971011#0_4'

# %%
# NARANONG
NARANONG_EB_0_0_LSXX = '25053626_0'
NARANONG_EB_0_1_XSRT = '25053626_1'
NARANONG_EB_1_0_XSXX = '824116559#0_0'
NARANONG_EB_1_1_XSXX = '824116559#0_1'
NARANONG_EB_2_0_XSXX = '824116558_0'
NARANONG_EB_2_1_XSXX = '824116558_1'
NARANONG_EB_2_2_XSXX = '824116558_2'
NARANONG_EB_3_0_XSXX = '25047032#1_0'
NARANONG_EB_3_1_XSRX = '25047032#1_1'
NARANONG_EB_4_0_LSXX = '756119203_0'
NARANONG_EB_4_1_XSXX = '756119203_1'
NARANONG_EB_5_0_LSXX = '157373209#1_0'
NARANONG_EB_5_1_XSRX = '157373209#1_1'

NARANONG_NB_0_0_XSXX = '824116551#0_0'
NARANONG_NB_0_1_XSRX = '824116551#0_1'
NARANONG_NB_1_0_LSXX = '157063979_0'
NARANONG_NB_1_1_XSXX = '157063979_1'
NARANONG_NB_1_2_XSXX = '157063979_2'
NARANONG_NB_2_0_XSXX = '-552779154#4_0'
NARANONG_NB_2_1_XSXX = '-552779154#4_1'

NARANONG_SB_0_0_LSXX = '824116544_0'
NARANONG_SB_0_1_XSXX = '824116544_1'
NARANONG_SB_0_2_XSRX = '824116544_2'
NARANONG_SB_1_0_LSXX = '459492916#0-AddedOffRampEdge_0'
NARANONG_SB_1_1_XSXX = '459492916#0-AddedOffRampEdge_1'
NARANONG_SB_1_2_XSXX = '459492916#0-AddedOffRampEdge_2'
NARANONG_SB_1_3_XSXX = '459492916#0-AddedOffRampEdge_3'
NARANONG_SB_2_0_XSXX = '459492916#0_0'
NARANONG_SB_2_1_XSXX = '459492916#0_1'
NARANONG_SB_2_2_XSXX = '459492916#0_2'
NARANONG_SB_2_3_XSXX = '459492916#0_3'

NARANONG_SW_0_0_LSXX = '824116550#0_0'
NARANONG_SW_0_1_XSRX = '824116550#0_1'
NARANONG_SW_1_0_XSXX = '824116549#0_0'
NARANONG_SW_1_1_XSXX = '824116549#0_1'
NARANONG_SW_1_2_XSXX = '824116549#0_2'
NARANONG_SW_1_3_XSXX = '824116549#0_3'
NARANONG_SW_2_0_XSXX = '9168676_0'
NARANONG_SW_2_1_XSXX = '9168676_1'
NARANONG_SW_2_2_XSXX = '9168676_2'

NARANONG_WB_0_0_LSXX = '338595767_0'
NARANONG_WB_0_1_XSXX = '338595767_1'
NARANONG_WB_0_2_XSXX = '338595767_2'
NARANONG_WB_0_3_XSRT = '338595767_3'
NARANONG_WB_1_0_XSXX = '482384850#2_0'
NARANONG_WB_1_1_XSXX = '482384850#2_1'
NARANONG_WB_1_2_XSXX = '482384850#2_2'
NARANONG_WB_2_0_LSXX = '482384850#1_0'
NARANONG_WB_2_1_XSXX = '482384850#1_1'
NARANONG_WB_2_2_XSXX = '482384850#1_2'
NARANONG_WB_3_0_XSXX = '482384850#1-AddedOnRampEdge_0'
NARANONG_WB_3_1_XSXX = '482384850#1-AddedOnRampEdge_1'
NARANONG_WB_3_2_XSXX = '482384850#1-AddedOnRampEdge_2'
NARANONG_WB_3_3_XSXX = '482384850#1-AddedOnRampEdge_3'
NARANONG_WB_4_0_XSXX = '482384850#0_0'
NARANONG_WB_4_1_XSXX = '482384850#0_1'
NARANONG_WB_4_2_XSXX = '482384850#0_2'

# %%
# SUNLAKAKHON
SUNLAKAKHON_EB_0_0_LSXX = '824116555#3_0'
SUNLAKAKHON_EB_0_1_XSXX = '824116555#3_1'
SUNLAKAKHON_EB_0_2_XSRT = '824116555#3_2'
SUNLAKAKHON_EB_1_0_XSXX = '824116555#0-AddedOffRampEdge_0'
SUNLAKAKHON_EB_1_1_XSXX = '824116555#0-AddedOffRampEdge_1'
SUNLAKAKHON_EB_1_2_XSXX = '824116555#0-AddedOffRampEdge_2'
SUNLAKAKHON_EB_1_3_XSRX = '824116555#0-AddedOffRampEdge_3'
SUNLAKAKHON_EB_2_0_XSXX = '824116555#0_0'
SUNLAKAKHON_EB_2_1_XSXX = '824116555#0_1'
SUNLAKAKHON_EB_2_2_XSXX = '824116555#0_2'
SUNLAKAKHON_EB_3_0_XSXX = '824116554_0'
SUNLAKAKHON_EB_3_1_XSXX = '824116554_1'
SUNLAKAKHON_EB_4_0_XSXX = '185563494_0'

SUNLAKAKHON_NB_0_0_LSXX = '153225687#13_0'
SUNLAKAKHON_NB_0_1_XSXX = '153225687#13_1'
SUNLAKAKHON_NB_0_2_XSRX = '153225687#13_2'
SUNLAKAKHON_NB_1_0_LSXX = '153225687#10-AddedOffRampEdge_0'
SUNLAKAKHON_NB_1_1_XSXX = '153225687#10-AddedOffRampEdge_1'
SUNLAKAKHON_NB_1_2_XSXX = '153225687#10-AddedOffRampEdge_2'
SUNLAKAKHON_NB_2_0_XSXX = '153225687#10_0'
SUNLAKAKHON_NB_2_1_XSXX = '153225687#10_1'
SUNLAKAKHON_NB_2_2_XSXX = '153225687#10_2'
SUNLAKAKHON_NB_3_0_LSXX = '153225687#9-AddedOnRampEdge_0'
SUNLAKAKHON_NB_3_1_XSXX = '153225687#9-AddedOnRampEdge_1'
SUNLAKAKHON_NB_3_2_XSXX = '153225687#9-AddedOnRampEdge_2'

SUNLAKAKHON_SB_0_0_LSXX = '321845932#1_0'
SUNLAKAKHON_SB_0_1_XSXX = '321845932#1_1'
SUNLAKAKHON_SB_0_2_XSRT = '321845932#1_2'
SUNLAKAKHON_SB_1_0_LSXX = '292571830-AddedOffRampEdge_0'
SUNLAKAKHON_SB_1_1_XSXX = '292571830-AddedOffRampEdge_1'
SUNLAKAKHON_SB_1_2_XSXX = '292571830-AddedOffRampEdge_2'
SUNLAKAKHON_SB_1_3_XSXX = '292571830-AddedOffRampEdge_3'
SUNLAKAKHON_SB_2_0_XSXX = '292571830_0'
SUNLAKAKHON_SB_2_1_XSXX = '292571830_1'
SUNLAKAKHON_SB_2_2_XSXX = '292571830_2'
SUNLAKAKHON_SB_3_0_LSXX = '482209833#1_0'
SUNLAKAKHON_SB_3_1_XSXX = '482209833#1_1'
SUNLAKAKHON_SB_3_2_XSXX = '482209833#1_2'
SUNLAKAKHON_SB_3_3_XSRX = '482209833#1_3'
SUNLAKAKHON_SB_4_0_XSXX = '482209833#0_0'
SUNLAKAKHON_SB_4_1_XSXX = '482209833#0_1'
SUNLAKAKHON_SB_4_2_XSXX = '482209833#0_2'

SUNLAKAKHON_WB_0_0_LSXX = '45033613#1_0'
SUNLAKAKHON_WB_0_1_XSXX = '45033613#1_1'
SUNLAKAKHON_WB_0_2_XSRX = '45033613#1_2'
SUNLAKAKHON_WB_1_0_XSXX = '45033613#0_0'
SUNLAKAKHON_WB_1_1_XSXX = '45033613#0_1'
SUNLAKAKHON_WB_1_2_XSXX = '45033613#0_2'
SUNLAKAKHON_WB_2_0_XSXX = '55814053#0_0'
SUNLAKAKHON_WB_2_1_XSXX = '55814053#0_1'

# %%
# RAMA4
RAMA4_EB_0_0_XSXX = '825786410_0'
RAMA4_EB_0_1_XSXX = '825786410_1'
RAMA4_EB_0_2_XSXX = '825786410_2'
RAMA4_EB_0_3_XSRT = '825786410_3'
RAMA4_EB_1_0_LSXX = '459492917#0_0'
RAMA4_EB_1_1_XSXX = '459492917#0_1'
RAMA4_EB_1_2_XSXX = '459492917#0_2'
RAMA4_EB_1_3_XSXX = '459492917#0_3'
RAMA4_EB_1_4_XSXX = '459492917#0_4'
# KLONGTEI EB

RAMA4_NB_0_0_XSXX = '824116545_0'
RAMA4_NB_0_1_XSXX = '824116545_1'
RAMA4_NB_0_2_XSRT = '824116545_2'
RAMA4_NB_1_0_LSXX = '824116548_0'
RAMA4_NB_1_1_XSXX = '824116548_1'
RAMA4_NB_1_2_XSXX = '824116548_2'
RAMA4_NB_1_3_XSXX = '824116548_3'
RAMA4_NB_2_0_XSXX = '824116547_0'
RAMA4_NB_2_1_XSXX = '824116547_1'
RAMA4_NB_2_2_XSXX = '824116547_2'
RAMA4_NB_3_0_XSXX = '338595771#1_0'
RAMA4_NB_3_1_XSXX = '338595771#1_1'

RAMA4_SB_0_0_XSXX = '821785867_0'
RAMA4_SB_0_1_XSXX = '821785867_1'
RAMA4_SB_0_2_XSRT = '821785867_2'
RAMA4_SB_1_0_LSXX = '821785869#0_0'
RAMA4_SB_1_1_XSXX = '821785869#0_1'
RAMA4_SB_1_2_XSXX = '821785869#0_2'
RAMA4_SB_1_3_XSXX = '821785869#0_3'
RAMA4_SB_2_0_XSXX = '825786414_0'
RAMA4_SB_2_1_XSXX = '825786414_1'
RAMA4_SB_2_2_XSXX = '825786414_2'
RAMA4_SB_3_0_XSXX = '25053655#0-AddedOffRampEdge_0'
RAMA4_SB_3_1_XSXX = '25053655#0-AddedOffRampEdge_1'
RAMA4_SB_3_2_XSXX = '25053655#0-AddedOffRampEdge_2'
RAMA4_SB_3_3_XSRX = '25053655#0-AddedOffRampEdge_3'
RAMA4_SB_4_0_XSXX = '25053655#0_0'
RAMA4_SB_4_1_XSXX = '25053655#0_1'
RAMA4_SB_4_2_XSXX = '25053655#0_2'
RAMA4_SB_5_0_XSXX = '453680009#0-AddedOffRampEdge_0'
RAMA4_SB_5_1_XSXX = '453680009#0-AddedOffRampEdge_1'
RAMA4_SB_5_2_XSXX = '453680009#0-AddedOffRampEdge_2'
RAMA4_SB_5_3_XSXX = '453680009#0-AddedOffRampEdge_3'
RAMA4_SB_5_4_XSXX = '453680009#0-AddedOffRampEdge_4'

RAMA4_WB_0_0_XSXX = '825786416_0'
RAMA4_WB_0_1_XSXX = '825786416_1'
RAMA4_WB_0_2_XSXX = '825786416_2'
RAMA4_WB_0_3_XSXX = '825786416_3'
RAMA4_WB_0_4_XSRT = '825786416_4'
RAMA4_WB_1_0_LSXX = '825786415_0'
RAMA4_WB_1_1_XSXX = '825786415_1'
RAMA4_WB_1_2_XSXX = '825786415_2'
RAMA4_WB_1_3_XSXX = '825786415_3'
RAMA4_WB_1_4_XSXX = '825786415_4'
RAMA4_WB_1_5_XSXX = '825786415_5'
RAMA4_WB_2_0_XSXX = '820373198#0_0'
RAMA4_WB_2_1_XSXX = '820373198#0_1'
RAMA4_WB_2_2_XSXX = '820373198#0_2'
RAMA4_WB_2_3_XSXX = '820373198#0_3'
RAMA4_WB_3_0_XSXX = '820373196#0_0'
RAMA4_WB_3_1_XSXX = '820373196#0_1'
RAMA4_WB_3_2_XSXX = '820373196#0_2'
RAMA4_WB_4_0_XSXX = '820373195_0'
RAMA4_WB_4_1_XSXX = '820373195_1'
RAMA4_WB_5_0_LSXX = '482209831#2_0'
RAMA4_WB_5_1_XSXX = '482209831#2_1'
RAMA4_WB_5_2_XSXX = '482209831#2_2'
RAMA4_WB_6_0_LSXX = '482209831#0_0'
RAMA4_WB_6_1_XSXX = '482209831#0_1'
RAMA4_WB_6_2_XSXX = '482209831#0_2'

# %%
MASUKGRIDLOCK_ARI_NB_0_0_LSXX = '-453962283#3_0'
MASUKGRIDLOCK_MASUK_WB_0_0_LSRX = '156261350#0_0'
MASUKGRIDLOCK_ATTHAKAWI_SB_0_0_XSRT = '27702347#0_0'
MASUKGRIDLOCK_ATTHAKAWI_SB_1_0_LSXT = '27702347#4_0'
MASUKGRIDLOCK_ATTHAKAWI_SB_2_0_LXXX = '27702347#6_0'
MASUKGRIDLOCK_SUKHUMVUT22_SB_0_0_XSXX = '-453669106#1_0'
MASUKGRIDLOCK_SUKHUMVUT24_SB_0_0_XSXX = '156261358#0_0'

# %%
# ONNUT
ONNUT_EB_0_0_LSXX = '-93727606#1_0'

ONNUT_NB_0_0_LSXX = '751454884#3_0'
ONNUT_NB_0_1_XSXX = '751454884#3_1'
ONNUT_NB_0_2_XSXX = '751454884#3_2'
ONNUT_NB_1_0_LSXX = '751454884#2_0'
ONNUT_NB_1_1_XSXX = '751454884#2_1'
ONNUT_NB_1_2_XSXX = '751454884#2_2'
ONNUT_NB_2_0_XSXX = '751454884#1_0'
ONNUT_NB_2_1_XSXX = '751454884#1_1'
ONNUT_NB_2_2_XSXX = '751454884#1_2'

ONNUT_SB_0_0_LSXX = '824116560#3_0'
ONNUT_SB_0_1_XSXX = '824116560#3_1'
ONNUT_SB_0_2_XSXX = '824116560#3_2'
ONNUT_SB_0_3_XSXX = '824116560#3_3'
ONNUT_SB_1_0_LSXX = '824116560#2_0'
ONNUT_SB_1_1_XSXX = '824116560#2_1'
ONNUT_SB_1_2_XSXX = '824116560#2_2'
ONNUT_SB_1_3_XSXX = '824116560#2_3'
ONNUT_SB_2_0_LSXX = '824116560#1_0'
ONNUT_SB_2_1_XSXX = '824116560#1_1'
ONNUT_SB_2_2_XSXX = '824116560#1_2'
ONNUT_SB_2_3_XSXX = '824116560#1_3'
ONNUT_SB_3_0_LSXX = '824116560#0_0'
ONNUT_SB_3_1_XSXX = '824116560#0_1'
ONNUT_SB_3_2_XSXX = '824116560#0_2'
ONNUT_SB_3_3_XSXX = '824116560#0_3'
ONNUT_SB_4_0_XSXX = '824816455_0'
ONNUT_SB_4_1_XSXX = '824816455_1'
ONNUT_SB_4_2_XSXX = '824816455_2'

ONNUT_WB_0_0_LSXX = '156591171#2_0'
ONNUT_WB_0_1_XSXX = '156591171#2_1'
ONNUT_WB_0_2_XSRX = '156591171#2_2'
ONNUT_WB_1_0_XSXX = '156591171#0_0'
ONNUT_WB_1_1_XSXX = '156591171#0_1'
ONNUT_WB_1_2_XSRT = '156591171#0_2'
ONNUT_WB_2_0_XSXX = '-824456409#0_0'
ONNUT_WB_2_1_XSRT = '-824456409#0_1'

# %%
import csv

# %%
namelane = open("NameLane.txt", "r") 
with open('namelane.csv', 'w') as csv_file:
    header = ['name', 'id']
    writer = csv.DictWriter(csv_file, fieldnames = header)
    writer.writeheader()
    for l in namelane:
        l = l.strip().split(' ')
        if len(l) >= 3:
#             print(l[0],l[2][1:-1])
            writer.writerow({'name': l[0],'id': l[2][1:-1]})

# %%
namelane = open("NameLane_KASEMRAT.txt", "r") 
with open('namelane_KASEMRAT.csv', 'w') as csv_file:
    header = ['name', 'id']
    writer = csv.DictWriter(csv_file, fieldnames = header)
    writer.writeheader()
    for l in namelane:
        l = l.strip().split(' ')
        if len(l) >= 3:
#             print(l[0],l[2][1:-1])
            writer.writerow({'name': l[0],'id': l[2][1:-1]})

# %%
namelane = open("NameLane_ONNUT.txt", "r") 
with open('namelane_ONNUT.csv', 'w') as csv_file:
    header = ['name', 'id']
    writer = csv.DictWriter(csv_file, fieldnames = header)
    writer.writeheader()
    for l in namelane:
        l = l.strip().split(' ')
        if len(l) >= 3:
#             print(l[0],l[2][1:-1])
            writer.writerow({'name': l[0],'id': l[2][1:-1]})

# %%
namelane = open("NameLane_ONNUT.txt", "r") 
out = '['
for l in namelane:
    l = l.strip().split(' ')
    if len(l) >= 3:
        out+="NAME.loc['"+l[0]+"','id'],"
print(out[:-1]+']')
# Out:
# [NAME.loc['ONNUT_EB_0_0_LSXX','id'],NAME.loc['ONNUT_NB_0_0_LSXX','id'],NAME.loc['ONNUT_NB_0_1_XSXX','id'],NAME.loc['ONNUT_NB_0_2_XSXX','id'],NAME.loc['ONNUT_NB_1_0_LSXX','id'],NAME.loc['ONNUT_NB_1_1_XSXX','id'],NAME.loc['ONNUT_NB_1_2_XSXX','id'],NAME.loc['ONNUT_NB_2_0_XSXX','id'],NAME.loc['ONNUT_NB_2_1_XSXX','id'],NAME.loc['ONNUT_NB_2_2_XSXX','id'],NAME.loc['ONNUT_SB_0_0_LSXX','id'],NAME.loc['ONNUT_SB_0_1_XSXX','id'],NAME.loc['ONNUT_SB_0_2_XSXX','id'],NAME.loc['ONNUT_SB_0_3_XSXX','id'],NAME.loc['ONNUT_SB_1_0_LSXX','id'],NAME.loc['ONNUT_SB_1_1_XSXX','id'],NAME.loc['ONNUT_SB_1_2_XSXX','id'],NAME.loc['ONNUT_SB_1_3_XSXX','id'],NAME.loc['ONNUT_SB_2_0_LSXX','id'],NAME.loc['ONNUT_SB_2_1_XSXX','id'],NAME.loc['ONNUT_SB_2_2_XSXX','id'],NAME.loc['ONNUT_SB_2_3_XSXX','id'],NAME.loc['ONNUT_SB_3_0_LSXX','id'],NAME.loc['ONNUT_SB_3_1_XSXX','id'],NAME.loc['ONNUT_SB_3_2_XSXX','id'],NAME.loc['ONNUT_SB_3_3_XSXX','id'],NAME.loc['ONNUT_SB_4_0_XSXX','id'],NAME.loc['ONNUT_SB_4_1_XSXX','id'],NAME.loc['ONNUT_S
# ...

# %%
namelane = open("NameLane.txt", "r") 
out = '['
for l in namelane:
    l = l.strip().split(' ')
    if len(l) >= 3:
        if l[0][0:8] == 'RAMA4_EB' or l[0][0:11] == 'KLONGTEI_EB':
            out+="NAME.loc['"+l[0]+"','id'],"
print(out[:-1]+']')
# Out:
# [NAME.loc['KLONGTEI_EB_0_0_XSXX','id'],NAME.loc['KLONGTEI_EB_0_1_XSXX','id'],NAME.loc['KLONGTEI_EB_0_2_XSXX','id'],NAME.loc['KLONGTEI_EB_0_3_XSXX','id'],NAME.loc['KLONGTEI_EB_0_4_XSRT','id'],NAME.loc['KLONGTEI_EB_1_0_XSXX','id'],NAME.loc['KLONGTEI_EB_1_1_XSXX','id'],NAME.loc['KLONGTEI_EB_1_2_XSXX','id'],NAME.loc['KLONGTEI_EB_1_3_XSXX','id'],NAME.loc['KLONGTEI_EB_2_0_LSXX','id'],NAME.loc['KLONGTEI_EB_2_1_XSXX','id'],NAME.loc['KLONGTEI_EB_2_2_XSXX','id'],NAME.loc['KLONGTEI_EB_2_3_XSXX','id'],NAME.loc['KLONGTEI_EB_3_0_LSXX','id'],NAME.loc['KLONGTEI_EB_3_1_XSXX','id'],NAME.loc['KLONGTEI_EB_4_0_XSXX','id'],NAME.loc['KLONGTEI_EB_4_1_XSXX','id'],NAME.loc['KLONGTEI_EB_4_2_XSXX','id'],NAME.loc['KLONGTEI_EB_4_3_XSXX','id'],NAME.loc['KLONGTEI_EB_4_4_XSXX','id'],NAME.loc['KLONGTEI_EB_5_0_XSXX','id'],NAME.loc['KLONGTEI_EB_5_1_XSXX','id'],NAME.loc['KLONGTEI_EB_5_2_XSXX','id'],NAME.loc['KLONGTEI_EB_5_3_XSXX','id'],NAME.loc['RAMA4_EB_0_0_XSXX','id'],NAME.loc['RAMA4_EB_0_1_XSXX','id'],NAME.loc['RAMA4
# ...

# %%
namelane = open("NameLane.txt", "r") 
out = '['
for l in namelane:
    l = l.strip().split(' ')
    if len(l) >= 3:
        if l[0][0:8] == 'RAMA4_SB':
            out+="NAME.loc['"+l[0]+"','id'],"
print(out[:-1]+']')
# Out:
# [NAME.loc['RAMA4_SB_0_0_XSXX','id'],NAME.loc['RAMA4_SB_0_1_XSXX','id'],NAME.loc['RAMA4_SB_0_2_XSRT','id'],NAME.loc['RAMA4_SB_1_0_LSXX','id'],NAME.loc['RAMA4_SB_1_1_XSXX','id'],NAME.loc['RAMA4_SB_1_2_XSXX','id'],NAME.loc['RAMA4_SB_1_3_XSXX','id'],NAME.loc['RAMA4_SB_2_0_XSXX','id'],NAME.loc['RAMA4_SB_2_1_XSXX','id'],NAME.loc['RAMA4_SB_2_2_XSXX','id'],NAME.loc['RAMA4_SB_3_0_XSXX','id'],NAME.loc['RAMA4_SB_3_1_XSXX','id'],NAME.loc['RAMA4_SB_3_2_XSXX','id'],NAME.loc['RAMA4_SB_3_3_XSRX','id'],NAME.loc['RAMA4_SB_4_0_XSXX','id'],NAME.loc['RAMA4_SB_4_1_XSXX','id'],NAME.loc['RAMA4_SB_4_2_XSXX','id'],NAME.loc['RAMA4_SB_5_0_XSXX','id'],NAME.loc['RAMA4_SB_5_1_XSXX','id'],NAME.loc['RAMA4_SB_5_2_XSXX','id'],NAME.loc['RAMA4_SB_5_3_XSXX','id'],NAME.loc['RAMA4_SB_5_4_XSXX','id']]

# %%
namelane = open("NameLane.txt", "r") 
out = '['
for l in namelane:
    l = l.strip().split(' ')
    if len(l) >= 3:
        if l[0][0:11] == 'KLONGTEI_NB':
            out+="NAME.loc['"+l[0]+"','id'],"
print(out[:-1]+']')
# Out:
# [NAME.loc['KLONGTEI_NB_0_0_LSXX','id'],NAME.loc['KLONGTEI_NB_0_1_XSXX','id'],NAME.loc['KLONGTEI_NB_0_2_XSXX','id'],NAME.loc['KLONGTEI_NB_0_3_XSRT','id'],NAME.loc['KLONGTEI_NB_1_0_LSXX','id'],NAME.loc['KLONGTEI_NB_1_1_XSXX','id'],NAME.loc['KLONGTEI_NB_1_2_XSXX','id'],NAME.loc['KLONGTEI_NB_1_3_XSXX','id'],NAME.loc['KLONGTEI_NB_2_0_LSXX','id'],NAME.loc['KLONGTEI_NB_2_1_XSXX','id'],NAME.loc['KLONGTEI_NB_2_2_XSXX','id'],NAME.loc['KLONGTEI_NB_2_3_XSXX','id']]

# %%
namelane = open("NameLane_KASEMRAT.txt", "r") 
out = '['
for l in namelane:
    l = l.strip().split(' ')
    if len(l) >= 3:
        if l[0][0:5] == 'MASUKGRIDLOCK':
            out+="NAME.loc['"+l[0]+"','id'],"
print(out[:-1]+']')
# Out:
# ]

# %%
namelane = open("NameLane.txt", "r") 
out = '['
for l in namelane:
    l = l.strip().split(' ')
    if len(l) >= 3:
        if l[0][0:11] == 'KASEMRAT_NB':
            out+="NAME.loc['"+l[0]+"','id'],"
print(out[:-1]+']')
# Out:
# [NAME.loc['KASEMRAT_NB_0_0_LSXX','id'],NAME.loc['KASEMRAT_NB_0_1_XSXX','id'],NAME.loc['KASEMRAT_NB_0_2_XSRX','id'],NAME.loc['KASEMRAT_NB_1_0_LSXX','id'],NAME.loc['KASEMRAT_NB_1_1_XSXX','id'],NAME.loc['KASEMRAT_NB_1_2_XSXX','id'],NAME.loc['KASEMRAT_NB_2_0_XSXX','id'],NAME.loc['KASEMRAT_NB_2_1_XSXX','id'],NAME.loc['KASEMRAT_NB_3_0_LSXX','id'],NAME.loc['KASEMRAT_NB_3_1_XSXX','id'],NAME.loc['KASEMRAT_NB_3_2_XSXX','id'],NAME.loc['KASEMRAT_NB_3_3_XSRT','id'],NAME.loc['KASEMRAT_NB_4_0_XSXX','id'],NAME.loc['KASEMRAT_NB_4_1_XSXX','id'],NAME.loc['KASEMRAT_NB_4_2_XSXX','id'],NAME.loc['KASEMRAT_NB_5_0_XSXX','id'],NAME.loc['KASEMRAT_NB_5_1_XSXX','id'],NAME.loc['KASEMRAT_NB_5_2_XSXX','id'],NAME.loc['KASEMRAT_NB_5_3_XSXX','id'],NAME.loc['KASEMRAT_NB_6_0_XSXX','id'],NAME.loc['KASEMRAT_NB_6_1_XSXX','id'],NAME.loc['KASEMRAT_NB_6_2_XSXX','id'],NAME.loc['KASEMRAT_NB_7_0_LSXX','id'],NAME.loc['KASEMRAT_NB_7_1_XSXX','id'],NAME.loc['KASEMRAT_NB_7_2_XSRX','id'],NAME.loc['KASEMRAT_NB_8_0_LSXX','id'],NAME.loc[
# ...

# %%
namelane = open("NameLane.txt", "r") 
out = '['
for l in namelane:
    l = l.strip().split(' ')
    if len(l) >= 3:
        if l[0][0:14] == 'SUNLAKAKHON_NB':
            out+="NAME.loc['"+l[0]+"','id'],"
print(out[:-1]+']')
# Out:
# [NAME.loc['SUNLAKAKHON_NB_0_0_LSXX','id'],NAME.loc['SUNLAKAKHON_NB_0_1_XSXX','id'],NAME.loc['SUNLAKAKHON_NB_0_2_XSRX','id'],NAME.loc['SUNLAKAKHON_NB_1_0_LSXX','id'],NAME.loc['SUNLAKAKHON_NB_1_1_XSXX','id'],NAME.loc['SUNLAKAKHON_NB_1_2_XSXX','id'],NAME.loc['SUNLAKAKHON_NB_2_0_XSXX','id'],NAME.loc['SUNLAKAKHON_NB_2_1_XSXX','id'],NAME.loc['SUNLAKAKHON_NB_2_2_XSXX','id'],NAME.loc['SUNLAKAKHON_NB_3_0_LSXX','id'],NAME.loc['SUNLAKAKHON_NB_3_1_XSXX','id'],NAME.loc['SUNLAKAKHON_NB_3_2_XSXX','id']]

# %%
namelane = open("NameLane.txt", "r") 
out = '['
for l in namelane:
    l = l.strip().split(' ')
    if len(l) >= 3:
        if l[0][0:11] == 'NARANONG_NB':
            out+="NAME.loc['"+l[0]+"','id'],"
print(out[:-1]+']')
# Out:
# [NAME.loc['NARANONG_NB_1_0_XSXX','id'],NAME.loc['NARANONG_NB_1_1_XSRX','id'],NAME.loc['NARANONG_NB_2_0_LSXX','id'],NAME.loc['NARANONG_NB_2_1_XSXX','id'],NAME.loc['NARANONG_NB_2_2_XSXX','id'],NAME.loc['NARANONG_NB_3_0_XSXX','id'],NAME.loc['NARANONG_NB_3_1_XSXX','id']]
